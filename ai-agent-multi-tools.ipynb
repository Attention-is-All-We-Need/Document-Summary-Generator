# %%
#this notebook made in reference to 5 days ai agents intensive course with Google

# %%
#Istalling dependencies
# !pip install google-adk
# Out:
# Requirement already satisfied: google-adk in /usr/local/lib/python3.11/dist-packages (1.18.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /usr/local/lib/python3.11/dist-packages (from google-adk) (6.0.3)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from google-adk) (8.3.0)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (0.116.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (2.177.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.125.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /usr/local/lib/python3.11/dist-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (3.56.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (3.5.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.48.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /usr/local/lib/python3.11/dist-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.20.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (2.12.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.11/dist-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (2.0.41)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /usr/local/lib/python3.11/dist-packages (from google-adk) (0.47.2)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.11/dist-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /usr/local/lib/python3.11/dist-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (0.35.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /usr/local/lib/python3.11/dist-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.11/dist-packages (from authlib<2.0.0,>=1.5.1->google-adk) (46.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (6.33.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.35.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.4 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (2.4.3)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (1.7.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-secret-manager<3.0.0,>=2.22.0->google-adk) (1.74.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/lib/python3.11/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (2.7.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.11/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.11/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.11/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.11.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.11/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.3)
# Requirement already satisfied: alembic in /usr/local/lib/python3.11/dist-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<1.0.0,>=0.34.0->google-adk) (0.16.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.71.2)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.0.9)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.26.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.26.4)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.4.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21->shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2024.2.0)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: protobuf, cachetools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.0
#     Uninstalling protobuf-6.33.0:
#       Successfully uninstalled protobuf-6.33.0
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.1
#     Uninstalling cachetools-6.2.1:
#       Successfully uninstalled cachetools-6.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-cloud-translate 3.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.29.5 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Successfully installed cachetools-5.5.2 protobuf-5.29.5

# %%
#authenticate the key
import os
from kaggle_secrets import UserSecretsClient
try:
    UserSecretsClient=UserSecretsClient()#get_secret is a instance method so we created a instance here
    GEMINI_API_KEY=UserSecretsClient.get_secret("GEMINI_API_KEY")
    os.environ["GEMINI_API_KEY"]=GEMINI_API_KEY
    os.environ["GEMINI_GENAI_USE_VERTEXAI"]="FALSE"#this tells which backend to use for ADK
    print("Gemini api setup complete")
except Exception as e:
    print(f"add api key : details {e}")
# Out:
# Gemini api setup complete

# %%
#import components from ADK
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search, AgentTool, FunctionTool
from google.genai import types
print("imports successful")
# Out:
# imports successful

# %%
#retry options config
retry_config=types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504]
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
#running agent
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("what are latest technologies of AI?")
# Out:
#  ### Created new session: debug_session_id
#
# User > what are latest technologies of AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %%
#we cannot rely on previous multi agent because it based on instructions of prompt, this is unreliable because complex LLM might skip the given  order.
#let us build apipeline to solve this problem
#1. linear pipeline-SequentialAent-This is perfect for tasks that build on each other, but it's slow if the tasks are independent.
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print(" outline_agent created.")
# Out:
#  outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print(" writer_agent created.")
# Out:
#  writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print(" editor_agent created.")
# Out:
#  editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print(" Sequential Agent created.")
# Out:
#  Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Multi-Agent Systems: Your Secret Weapon for Smarter, More Agile Software Development
#
# In the fast-paced world of software development, efficiency, adaptability, and robust solutions are paramount. But what if there was a way to build systems that were not only powerful but also inherently more flexible and intelligent? Enter Multi-Agent Systems (MAS). If you're a software developer looking to level up your game, understanding MAS is no longer optional – it's a strategic advantage.
#
# ### 1. What Exactly Are Multi-Agent Systems (MAS)?
#
# *   **The Core Concept:** Imagine a team of independent, autonomous software "agents" working together, each with its own goals, capabilities, and decision-making processes, to achieve a larger, common objective. MAS are systems composed of these interacting agents.
# *   **Beyond Simple Automation:** Unlike traditional, monolithic software, MAS distribute intelligence and functionality. This means individual agents can be simpler, yet the collective system can tackle complex problems that would be difficult or impossible to solve with a single, unified program.
# *   **Key Characteristics:** Agents in MAS often exhibit characteristics like autonomy (acting without direct human intervention), reactivity (responding to their environment), proactivity (taking initiative to achieve goals), and social ability (communicating and cooperating with other agents).
#
# ### 2. Unlocking Development Efficiency and Agility
#
# *   **Modular Design & Reusability:** MAS naturally lend themselves to modular development. Each agent can be developed, tested, and debugged independently. This not only speeds up the development cycle but also makes it easier to reuse individual agents in different contexts or projects.
# *   **Scalability and Flexibility:** Need to handle more load? Simply add more agents. MAS can be scaled dynamically by adding or removing agents as needed, allowing your software to adapt to changing demands without requiring a complete system overhaul. This makes them incredibly flexible.
# *   **Easier Maintenance and Updates:** When an issue arises or a feature needs updating, you can often isolate the problem to a specific agent. This targeted approach simplifies maintenance and allows for quicker, less disruptive updates compared to modifying a large, interconnected codebase.
#
# ### 3. Building More Robust and Resilient Software
#
# *   **Decentralized Control & Fault Tolerance:** In a MAS, the failure of one agent doesn't necessarily bring down the entire system. Because control is distributed, other agents can often compensate for the loss, leading to more resilient and fault-tolerant applications.
# *   **Handling Complexity and Uncertainty:** MAS excel at tackling problems with inherent complexity and uncertainty. Agents can be designed to learn, adapt, and make decisions in dynamic environments, making them ideal for applications like real-time control, simulation, and complex optimization tasks.
# *   **Emergent Behavior and Collective Intelligence:** The interactions between individual agents can lead to emergent behaviors – complex patterns or solutions that weren't explicitly programmed into any single agent. This "collective intelligence" can lead to novel and highly effective problem-solving capabilities.
#
# ### 4. Real-World Applications and Your Next Project
#
# *   **From Smart Grids to Robotics:** MAS are already powering innovations in diverse fields, including smart energy grids, autonomous robotics, sophisticated game AI, supply chain management, financial trading systems, and even personal assistants.
# *   **Opportunities for Developers:** By embracing MAS principles, you can position yourself at the forefront of software innovation. Whether it's designing smarter IoT solutions, developing more adaptive AI, or creating systems that can learn and evolve, MAS offer a powerful new paradigm for tackling challenging software problems.
# *   **Start Exploring:** Begin by exploring MAS frameworks and libraries relevant to your preferred programming languages. Experiment with simple agent designs and gradually build up to more complex multi-agent architectures. The learning curve is an investment that promises significant returns.
#
# ### Conclusion: Embrace the Power of Collaboration for Your Code
#
# Multi-Agent Systems are more than just a theoretical concept; they are a practical and increasingly vital approach to building the next generation of intelligent, adaptable, and resilient software. By understanding and applying MAS principles, software developers can unlock new levels of efficiency, create more robust solutions, and pave the way for truly innovative applications. It's time to think beyond single threads and monolithic structures and embrace the power of collaborative intelligence for your code.
# WriterAgent > ## Level Up Your Code: Why Multi-Agent Systems are Your New Best Friend
#
# In today's rapidly evolving tech landscape, developers are constantly seeking ways to build smarter, more adaptable, and resilient software. If you're looking for a strategic edge, it's time to explore the world of Multi-Agent Systems (MAS). Forget monolithic structures; MAS offers a powerful paradigm shift.
#
# At its core, MAS involves a team of independent, autonomous software "agents" working collaboratively. Each agent has its own goals and decision-making capabilities, but together they tackle complex objectives that would be overwhelming for a single program. Think of them as specialized team members, each doing its part to achieve a larger goal.
#
# This distributed approach unlocks incredible benefits for developers. MAS naturally promotes **modular design**, making code easier to develop, test, and reuse. Need to handle increased demand? **Scalability** is a breeze – simply add more agents. Maintenance becomes less of a headache too, as you can often isolate issues to specific agents, enabling quicker, less disruptive updates.
#
# Beyond efficiency, MAS builds **robustness**. With decentralized control, the failure of one agent doesn't cripple the entire system. This fault tolerance is invaluable. Furthermore, MAS excels at handling complexity and uncertainty, enabling systems to learn, adapt, and even exhibit emergent behaviors – a form of collective intelligence. From smart grids to advanced robotics, MAS is already powering innovation. It's time to embrace collaborative intelligence and transform your software development.
# EditorAgent > ## Level Up Your Code: Why Multi-Agent Systems are Your New Best Friend
#
# In today's rapidly evolving tech landscape, developers are constantly seeking ways to build smarter, more adaptable, and resilient software. If you're looking for a strategic edge, it's time to explore the world of Multi-Agent Systems (MAS). Forget monolithic structures; MAS offers a powerful paradigm shift that can revolutionize your development approach.
#
# At its core, MAS involves a team of independent, autonomous software "agents" working collaboratively. Each agent possesses its own goals and decision-making capabilities, but together, they tackle complex objectives that would be overwhelming for a single program. Think of them as specialized team members, each contributing its unique skills to achieve a larger, overarching goal.
#
# This distributed approach unlocks incredible benefits for developers. MAS naturally promotes **modular design**, making code easier to develop, test, and reuse. Facing increased demand? **Scalability** becomes a breeze – simply add more agents to handle the load. Maintenance transforms from a headache into a streamlined process; you can often isolate issues to specific agents, enabling quicker, less disruptive updates without impacting the entire system.
#
# Beyond enhanced efficiency, MAS builds superior **robustness**. With decentralized control, the failure of one agent doesn't cripple the entire system. This inherent fault tolerance is invaluable, ensuring your applications remain operational even in the face of unexpected issues. Furthermore, MAS excels at handling complexity and uncertainty. They enable systems to learn, adapt, and even exhibit emergent behaviors – a form of collective intelligence that can lead to novel solutions. From smart grids to advanced robotics, MAS is already powering innovation across industries. It's time to embrace collaborative intelligence and transform your software development.

# %%
#Use Parallel when: Tasks are independent, speed matters, and you can execute concurrently
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print(" tech_researcher created.")
# Out:
#  tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print(" health_researcher created.")
# Out:
#  health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print(" finance_researcher created.")
# Out:
#  finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print(" aggregator_agent created.")
# Out:
#  aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print(" Parallel and Sequential Agents created.")
# Out:
#  Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > **AI/ML Trends Report: November 14, 2025**
#
# **Key Developments:**
#
# 1.  **Generative AI Advancements:** Generative AI continues its rapid evolution, expanding beyond text to create complex graphics, video, and music. Companies like Google (Imagen, Muse) and OpenAI (GPT models) are leading this charge, enabling new forms of content creation and artistic expression.
# 2.  **Explainable and Ethical AI:** As AI becomes more integrated into critical sectors like healthcare and finance, transparency in decision-making is paramount. Explainable AI (XAI) is gaining traction to ensure trust, fairness, and regulatory compliance.
# 3.  **AI-Driven Automation & Efficiency:** AI is increasingly automating business processes and enhancing operational efficiency across industries. This includes AI-powered cybersecurity for threat detection, predictive analytics for optimized resource allocation, and intelligent automation in manufacturing and retail.
#
# **Main Companies Involved:**
#
# *   **Tech Giants:** Google, Microsoft, Amazon, NVIDIA, Apple, Meta Platforms.
# *   **AI Specialists:** OpenAI, DeepMind, H2O.ai, Databricks, Stability AI, Synthesia.
#
# **Potential Impact:**
#
# These trends are revolutionizing industries by boosting productivity, enabling personalized experiences, and driving innovation. However, they also raise challenges in data privacy, ethical considerations, and the need for workforce adaptation.
# HealthResearcher > Here's a briefing on recent breakthroughs in Tech, Health, and Finance:
#
# **Health:** Gene therapy is rapidly advancing, with recent successes in treating inherited hearing loss and holding promise for genetic diseases and certain cancers. CAR T-cell therapy is showing new hope for brain cancers, and stem cell treatments are restoring vision. Within the next year, at-home diagnostic tests for multiple respiratory illnesses are expected.
#
# **Tech:** Agentic AI systems, capable of autonomous task execution and learning, are projected for significant enterprise adoption by 2028. Quantum computing continues to see breakthroughs, with IBM announcing advancements for increased circuit complexity and future fault-tolerant systems. Other innovations include ultra-low-power AI chips and new methods for controlling light within optical fibers.
#
# **Finance:** Blockchain and DeFi are transforming traditional financial services by offering secure, decentralized platforms for lending and smart contracts. Advancements in AI and machine learning are enhancing risk assessment and fund monitoring. The integration of IoT into banking aims for more personalized risk assessments and improved credit access.
# FinanceResearcher > Here's your daily executive briefing:
#
# **Technology Trends**
#
# *   **AI and Automation:** Generative AI continues its rapid integration across industries, driving automation in content creation, customer service, and software development. Expect AI to become more sophisticated in back-office functions and customer-facing roles like chatbots and AI assistants. The market for AI in financial services is projected for significant growth.
# *   **Agentic AI:** This advanced form of AI, capable of autonomous planning and action to achieve user-defined goals, is emerging as a key trend, promising "virtual coworkers" for complex workflows.
# *   **Advanced Connectivity:** Maturing 5G networks will enable high-speed applications, IoT advancements, and immersive experiences, paving the way for smart cities and improved mobile-centric services.
#
# **Health Trends**
#
# *   **Precision Medicine and Personalized Care:** Driven by AI and Machine Learning, healthcare is moving towards highly personalized treatments based on genetics, environment, and lifestyle.
# *   **Telehealth and Digital Health Tools:** The adoption of telehealth and other digital solutions, including remote monitoring, is crucial for increasing healthcare access, efficiency, and managing rising costs.
# *   **Gut Health and Mental Well-being:** Consumer focus on gut health is expected to continue, with growing research into the microbiome's impact on overall health. Mental health tech and integrated behavioral health services are also gaining prominence.
#
# **Finance Trends**
#
# *   **Embedded Finance and Open Banking:** Financial services are increasingly being integrated into non-financial platforms (embedded finance), supported by open banking initiatives that allow seamless data sharing.
# *   **Central Bank Digital Currencies (CBDCs):** CBDCs are emerging as a significant trend, with several countries progressing experiments, indicating a shift towards more digital global financial systems.
# *   **Sustainable Finance:** There's a growing demand for sustainable and ethical financial products, with a focus on ESG-driven solutions, green finance, and impact investing.
# AggregatorAgent > ## Executive Summary: Tech, Health, and Finance Briefing
#
# The convergence of Artificial Intelligence (AI) and advanced technologies is rapidly reshaping all sectors. Generative AI is revolutionizing content creation and operational efficiency, while the emergence of Agentic AI promises autonomous task execution, acting as "virtual coworkers." Concurrently, ethical and explainable AI (XAI) is becoming critical for trust and compliance, especially in sensitive areas like finance and healthcare.
#
# In healthcare, breakthroughs in gene therapy, CAR T-cell treatments, and stem cell therapies are offering new hope for genetic diseases, cancers, and vision restoration. Precision medicine, fueled by AI, is enabling personalized treatments, augmented by the rise of telehealth and digital health tools for increased access and efficiency. Consumer focus is also broadening to include gut health and mental well-being.
#
# Financially, blockchain, DeFi, and AI are transforming services through decentralized platforms, enhanced risk assessment, and personalized offerings via IoT integration. Embedded finance and open banking are integrating financial services into everyday platforms, while Central Bank Digital Currencies (CBDCs) signal a shift towards digital global systems. A growing emphasis on sustainable and ESG-driven finance is also evident. The overarching impact across all domains is enhanced productivity, personalized experiences, and innovation, alongside challenges in data privacy, ethics, and workforce adaptation.

# %%
#Loop when: Iterative improvement is needed, quality refinement matters, or you need repeated cycles.
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print(" initial_writer_agent created.")
# Out:
#  initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print(" critic_agent created.")
# Out:
#  critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print(" exit_loop function created.")
# Out:
#  exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print(" refiner_agent created.")
# Out:
#  refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print(" Loop and Sequential Agents created.")
# Out:
#  Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > The salt spray stung Elias’s weathered cheeks as he polished the great lamp, its beam slicing through the predawn gloom. For thirty years, the sea had been his only companion. Tonight, however, was different. Tucked beneath a loose stone in the lantern room, he found it: a map, not of ink and parchment, but of swirling, ethereal light.
#
# It pulsed with an inner luminescence, lines of sapphire and emerald tracing patterns he’d never seen. No landmasses he recognized, only celestial constellations twisted into abstract rivers and oceans. As he traced a luminous current with a calloused finger, a faint hum vibrated through the stone floor. The map shimmered, revealing a single, impossibly bright star. Elias, the solitary keeper, felt a pull, not of the tide, but of a destiny far beyond his lonely tower.
# CriticAgent > The story presents an intriguing premise with a strong hook. Elias's isolation and the discovery of the mystical map create immediate mystery and potential for grand adventure. The description of the map as "swirling, ethereal light" with "celestial constellations twisted into abstract rivers and oceans" is evocative and sets a unique tone.
#
# However, the story is very brief, leaving much to be desired in terms of plot development, character depth, and pacing.
#
# Here are a few actionable suggestions for improvement:
#
# 1.  **Expand on Elias's Character:** While his thirty years of solitary life are mentioned, we don't get a strong sense of *who* Elias is beyond his profession. What are his quiet desires or regrets? A brief internal reflection on his loneliness or a small, habitual action that reveals his personality could make his eventual "pull of destiny" more impactful.
# 2.  **Flesh out the Map's Discovery and Interaction:** The discovery is a bit abrupt. What prompted him to check beneath a loose stone? Was it a routine maintenance check, or did something else draw his attention? Similarly, the interaction with the map is very brief. What happens when he touches the luminous current? Does he see visions, feel a physical sensation beyond the hum, or does the map react more dramatically? Adding a sentence or two describing a more profound reaction or a glimpse of what the map represents would enhance the sense of wonder and mystery.
# 3.  **Hint at the "Destiny":** The story ends with Elias feeling a "pull, not of the tide, but of a destiny far beyond his lonely tower." While this is a good cliffhanger, it could be strengthened by offering a tiny, concrete hint of what that destiny might entail. For instance, does the bright star pulse in a specific direction, or does Elias suddenly recall an old legend or a dream that now seems relevant? This would give the reader a slightly clearer, albeit still mysterious, idea of where the story might go next.
# RefinerAgent > The salt spray stung Elias’s weathered cheeks as he polished the great lamp, its beam slicing through the predawn gloom. For thirty years, the sea had been his only companion, each crashing wave a familiar, if lonely, song. He’d long since made peace with the quiet rhythm of his life, his only indulgence the small, carved seabird he’d kept in his pocket, a habit from a time before the tower. Tonight, however, was different. A persistent draft, unusual for the sealed lantern room, had drawn his attention to a loose stone near the base of the lamp. As he pried it open, a faint, otherworldly glow spilled out. Tucked within the cavity was a map, not of ink and parchment, but of swirling, ethereal light.
#
# It pulsed with an inner luminescence, lines of sapphire and emerald tracing patterns he’d never seen. No landmasses he recognized, only celestial constellations twisted into abstract rivers and oceans. Hesitantly, Elias reached out, his calloused finger tracing a luminous current. The map flared, and he felt not just a hum vibrating through the stone floor, but a jolt that shot up his arm, bringing with it fragmented images of star-dusted voids and silent, alien shores. The map shimmered, resolving into a single, impossibly bright star that pulsed with a gentle, insistent rhythm. It seemed to point, not to any direction on his known world, but towards a point in the vast, star-strewn sky. Suddenly, an old fisherman's tale his grandfather used to tell – a yarn about a star that sang to those lost at sea – echoed in Elias’s mind. The solitary keeper felt a pull, a yearning that was not of the tide, but of a destiny that had been waiting, hidden amongst the stars, far beyond his lonely tower.
# CriticAgent > The story has been significantly improved. The added detail about the "persistent draft" provides a more logical reason for Elias investigating the loose stone, making the discovery feel more earned. The description of the map's interaction has also been enhanced with the "jolt that shot up his arm, bringing with it fragmented images of star-dusted voids and silent, alien shores," which adds a more immediate and personal connection to the celestial phenomenon. The inclusion of the grandfather's tale effectively ties the fantastical discovery to Elias's past and grounds the abstract "destiny" in a tangible piece of folklore.
#
# However, the pacing still feels a little rushed at the very end, and the concluding sentence, while thematic, could be slightly more impactful by focusing on Elias's immediate internal shift.
#
# Here is one specific, actionable suggestion for improvement:
#
# 1.  **Refine the concluding sentence for immediate impact:** The current ending is good, but slightly rephrasing the final sentence to emphasize Elias's immediate internal decision or feeling would create a stronger sense of closure for this scene and a more compelling hook for what comes next. Instead of "The solitary keeper felt a pull, a yearning that was not of the tide, but of a destiny that had been waiting, hidden amongst the stars, far beyond his lonely tower," consider something like: "The solitary keeper, his hand still tingling, felt a pull that drowned out the roar of the waves – a yearning for the star that sang, a destiny he could no longer ignore, waiting far beyond his lonely tower." This shifts the focus slightly to his active feeling and the direct comparison to his known world.
# RefinerAgent > The salt spray stung Elias’s weathered cheeks as he polished the great lamp, its beam slicing through the predawn gloom. For thirty years, the sea had been his only companion, each crashing wave a familiar, if lonely, song. He’d long since made peace with the quiet rhythm of his life, his only indulgence the small, carved seabird he’d kept in his pocket, a habit from a time before the tower. Tonight, however, was different. A persistent draft, unusual for the sealed lantern room, had drawn his attention to a loose stone near the base of the lamp. As he pried it open, a faint, otherworldly glow spilled out. Tucked within the cavity was a map, not of ink and parchment, but of swirling, ethereal light.
#
# It pulsed with an inner luminescence, lines of sapphire and emerald tracing patterns he’d never seen. No landmasses he recognized, only celestial constellations twisted into abstract rivers and oceans. Hesitantly, Elias reached out, his calloused finger tracing a luminous current. The map flared, and he felt not just a hum vibrating through the stone floor, but a jolt that shot up his arm, bringing with it fragmented images of star-dusted voids and silent, alien shores. The map shimmered, resolving into a single, impossibly bright star that pulsed with a gentle, insistent rhythm. It seemed to point, not to any direction on his known world, but towards a point in the vast, star-strewn sky. Suddenly, an old fisherman's tale his grandfather used to tell – a yarn about a star that sang to those lost at sea – echoed in Elias’s mind. The solitary keeper, his hand still tingling, felt a pull that drowned out the roar of the waves – a yearning for the star that sang, a destiny he could no longer ignore, waiting far beyond his lonely tower.
